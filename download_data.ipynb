# %%
import minerl
minerl.data.download('/app/code/minerl-data')
# Out:
# YOUR DATASET IS OUT OF DATE! The latest is on version v1 but yours is lower!
#
# 	Re-download the data using `minerl.data.download(directory=/app/code/minerl-data)`
# Deleting existing data and forcing a data update!
# ...
