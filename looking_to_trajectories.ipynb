# %%
import minerl
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import pandas as pd

data = minerl.data.make(
    'MineRLObtainDiamond-v0',
    data_dir='/app/code/minerl-data')

data_iter = data.sarsd_iter(max_sequence_len=8, num_epochs=1, include_metadata=True,)
all_actions = []

# %%
current_state, action, reward, next_state, done, meta = next(data_iter)
plt.figure()
plt.imshow(current_state['pov'][0])

# %%
plt.figure()
plt.imshow(current_state['pov'][7])

# %%
for i in range(1):
   
    
    
    # Prepare for next step and store scores
    plt.imshow(env.render(mode='rgb_array'))     
    display.display(plt.gcf())
    clear_output(wait=True)
    obs = next_obs
    score += rew
    current_score.append(score)
    
    net_reward += rew
    actions.append((env_act, net_reward))
    
    print('equipped:', obs['equipped_items'])
    print('inventory:', obs['inventory'])
