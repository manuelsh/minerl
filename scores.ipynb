# %%
import pickle
import matplotlib.pyplot as plt

# %%
scores = pickle.load(open('scores.pickle','rb'))
plt.plot(scores)
plt.grid()

# %%
scores
# Out:
# [-8.39520263671875,
#  -6.5391845703125,
#  2.4545059204101562,
#  3.441608428955078,
#  -0.703160285949707,
#  2.4788665771484375,
#  -1.8763961791992188,
#  -1.400726318359375,
#  0.6743659973144531,
#  -1.6055374145507812,
#  -0.8267364501953125,
#  2.0131988525390625,
#  -9.331132888793945,
#  7.031871795654297,
#  -0.205322265625,
#  -5.233623504638672,
#  5.560436248779297,
#  -3.9488983154296875,
#  2.2059707641601562,
#  -0.0046234130859375,
#  0.08277130126953125,
#  -1.6341781616210938,
#  -0.16777801513671875,
#  -3.8365859985351562,
#  0.264617919921875,
#  1.4989547729492188,
#  10.028953552246094,
#  -2.1729278564453125]

# %%
scores = pickle.load(open('scores.pickle','rb'))
plt.plot(scores)
plt.grid()
